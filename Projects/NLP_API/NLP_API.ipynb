# %%
from currentsapi import CurrentsAPI

# %%
api = CurrentsAPI(api_key='dRWQojBGS4lfWFNX2CpLc2LjfKEwgxVbj5PC2eKdd7cOv1qL')

# %%
api.latest_news()
# Out:
# {'status': 'ok',
#  'news': [{'id': 'afc3da87-7463-40a2-8d63-b9440b3549dd',
#    'title': 'Oxford vaccine: Will it provide lasting immunity? | DW | 22.07.2020',
#    'description': 'A COVID-19 vaccine in development at Oxford University has shown an effective immune response for 56 days. But will it last longer? Trials are ongoing....',
#    'url': 'https://www.dw.com/en/oxford-vaccine-will-it-provide-lasting-immunity/a-54268557',
#    'author': 'DW.COM, Deutsche Welle',
#    'image': 'https://www.dw.com/image/54185067_401.jpg',
#    'language': 'en',
#    'category': ['science'],
#    'published': '2020-07-22 15:29:00 +0000'},
#   {'id': '85de490c-e010-4e35-a3bd-bb0d4f13799b',
#    'title': 'Beyerdynamic’s MMX 300 gaming headset are set to bring hi-fi to gaming',
#    'description': 'Down for a second round...',
#    'url': 'https://www.stuff.tv/in/hot-stuff/audio/beyerdynamics-mmx-300-gaming-headset-are-set-bring-hi-fi-gaming',
#    'author': 'Khumail Thakur',
# ...

# %%
search2 = api.search(keywords='Trump')

# %%
search2
# Out:
# {'status': 'ok',
#  'news': [{'id': '195940e5-04a8-484d-addf-6c9d7b660e55',
#    'title': 'The President Wants You To Know He Can Memorize Five Words — In Order!',
#    'description': '"It\'s actually not that easy. But, for me, it was easy," Trump said of the test, which is used in diagnosing Alzheimer\'s.View Entire Post ›...',
#    'url': 'https://www.buzzfeednews.com/article/juliareinstein/trump-person-woman-man-camera-tv-cognitive-dementia-test',
#    'author': 'https://www.buzzfeednews.com/article/buzzfeednews/about-buzzfeed-news',
#    'image': 'None',
#    'language': 'en',
#    'category': ['politics', 'world'],
#    'published': '2020-07-23 18:24:18 +0000'},
#   {'id': '6a97a479-8e12-47c9-8382-1052f31bfcea',
#    'title': 'Revenge of the Never Trumpers: Meet the Republican Dissidents Fighting to Push Donald Trump Out of Office',
#    'description': "In the final stretch of the President's term, the Never Trumpers could finally have their revenge...",
# ...
