# %%
from matplotlib.backends.backend_qt5agg import FigureCanvasQTAgg
from matplotlib.figure import Figure
from datetime import date

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
#%matplotlib inline
import pyqtgraph as pg
import requests
import json

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import sklearn.metrics as sm

# %%
import urllib.request as urllib2
from PyQt5 import QtCore, QtGui,QtWidgets
from datetime import date 
import requests
import logging
import csv 
from PyQt5.QtWidgets import QMessageBox

# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'GUI.ui'
#
# Created by: PyQt5 UI code generator 5.15.0
#
# WARNING: Any manual changes made to this file will be lost when pyuic5 is
# run again.  Do not edit this file unless you know what you are doing.


class Ui_MainWindow(object):
    
    dataset = object
    find_duplication = []
    
    def setupUi(self, MainWindow):
       
        MainWindow.setObjectName("Search City Weather API")
        MainWindow.resize(1200, 1600)
        palette = QtGui.QPalette()
        brush = QtGui.QBrush(QtGui.QColor(56, 137, 236))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Active, QtGui.QPalette.Button, brush)
        brush = QtGui.QBrush(QtGui.QColor(56, 137, 236))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Inactive, QtGui.QPalette.Button, brush)
        brush = QtGui.QBrush(QtGui.QColor(56, 137, 236))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Disabled, QtGui.QPalette.Button, brush)
        MainWindow.setPalette(palette)
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setObjectName("centralwidget")
        self.groupBox = QtWidgets.QGroupBox(self.centralwidget)
        self.groupBox.setGeometry(QtCore.QRect(690, 20, 221, 121))
        font = QtGui.QFont()
        font.setPointSize(14)
        
        
        self.groupBox.setFont(font)
        self.groupBox.setObjectName("groupBox")
        self.pushButton = QtWidgets.QPushButton(self.groupBox)
        self.pushButton.setGeometry(QtCore.QRect(10, 90, 200, 32))
        self.pushButton.setObjectName("Upload Cities List To Server")
        
        
        self.label_4 = QtWidgets.QLabel(self.centralwidget)
        self.label_4.setGeometry(QtCore.QRect(360, 440, 60, 16))
        self.label_4.setObjectName("label_4")
        self.frame = QtWidgets.QFrame(self.centralwidget)
        self.frame.setGeometry(QtCore.QRect(20, 20, 611, 291))
        self.frame.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame.setObjectName("frame")
        #self.label_2 = QtWidgets.QLabel(self.frame)
        #self.label_2.setGeometry(QtCore.QRect(310, 20, 60, 16))
        #self.label_2.setObjectName("label_2")
        
        self.listView = QtWidgets.QListWidget(self.frame)
        self.listView.setGeometry(QtCore.QRect(280, 40, 301, 192))
      
       
        
        self.listView.setObjectName("listView")
        
      
        
      
        
        self.treeWidget = QtWidgets.QTreeWidget(self.frame)
        self.treeWidget.setGeometry(QtCore.QRect(0, 40, 256, 192))
        self.treeWidget.setObjectName("treeWidget")
        self.treeWidget.headerItem().setText(0, "Locate City By Clicking On State")
       
        self.treeWidget.setSortingEnabled(True)
        #self.treeWidget.sortByColumn(self, 1 )
        selmodel = self.treeWidget.selectionModel()
        selmodel.selectionChanged.connect(self.on_treeview_clicked)
        
       
        #self.treeWidget.clicked.connect(self.on_treeview_clicked)
        
        
        self.label = QtWidgets.QLabel(self.frame)
        self.label.setGeometry(QtCore.QRect(10, 10, 101, 16))
        self.label.setObjectName("label")
        
        self.btn_run_program = QtWidgets.QPushButton(self.frame)
        self.btn_run_program.setGeometry(QtCore.QRect(380, 250, 113, 32))
        
        self.btn_clear_listview = QtWidgets.QPushButton(self.frame)
        self.btn_clear_listview.setGeometry(QtCore.QRect(50, 250, 113, 32))
        
        self.btn_clear_listview.clicked.connect(self.collaspe_treeview_list)
        
        self.btn_run_program.clicked.connect(self.call_api_with_list) 
       
        palette = QtGui.QPalette()
        brush = QtGui.QBrush(QtGui.QColor(0, 0, 0))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Active, QtGui.QPalette.WindowText, brush)
        brush = QtGui.QBrush(QtGui.QColor(233, 58, 68))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Active, QtGui.QPalette.Button, brush)
        brush = QtGui.QBrush(QtGui.QColor(255, 159, 164))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Active, QtGui.QPalette.Light, brush)
        brush = QtGui.QBrush(QtGui.QColor(244, 108, 116))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Active, QtGui.QPalette.Midlight, brush)
        brush = QtGui.QBrush(QtGui.QColor(116, 29, 34))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Active, QtGui.QPalette.Dark, brush)
        brush = QtGui.QBrush(QtGui.QColor(155, 39, 45))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Active, QtGui.QPalette.Mid, brush)
        brush = QtGui.QBrush(QtGui.QColor(0, 0, 0))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Active, QtGui.QPalette.Text, brush)
        brush = QtGui.QBrush(QtGui.QColor(255, 255, 255))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Active, QtGui.QPalette.BrightText, brush)
        brush = QtGui.QBrush(QtGui.QColor(0, 0, 0))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Active, QtGui.QPalette.ButtonText, brush)
        brush = QtGui.QBrush(QtGui.QColor(255, 255, 255))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Active, QtGui.QPalette.Base, brush)
        brush = QtGui.QBrush(QtGui.QColor(233, 58, 68))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Active, QtGui.QPalette.Window, brush)
        brush = QtGui.QBrush(QtGui.QColor(0, 0, 0))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Active, QtGui.QPalette.Shadow, brush)
        brush = QtGui.QBrush(QtGui.QColor(244, 156, 161))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Active, QtGui.QPalette.AlternateBase, brush)
        brush = QtGui.QBrush(QtGui.QColor(255, 255, 220))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Active, QtGui.QPalette.ToolTipBase, brush)
        brush = QtGui.QBrush(QtGui.QColor(0, 0, 0))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Active, QtGui.QPalette.ToolTipText, brush)
        brush = QtGui.QBrush(QtGui.QColor(0, 0, 0))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Inactive, QtGui.QPalette.WindowText, brush)
        brush = QtGui.QBrush(QtGui.QColor(233, 58, 68))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Inactive, QtGui.QPalette.Button, brush)
        brush = QtGui.QBrush(QtGui.QColor(255, 159, 164))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Inactive, QtGui.QPalette.Light, brush)
        brush = QtGui.QBrush(QtGui.QColor(244, 108, 116))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Inactive, QtGui.QPalette.Midlight, brush)
        brush = QtGui.QBrush(QtGui.QColor(116, 29, 34))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Inactive, QtGui.QPalette.Dark, brush)
        brush = QtGui.QBrush(QtGui.QColor(155, 39, 45))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Inactive, QtGui.QPalette.Mid, brush)
        brush = QtGui.QBrush(QtGui.QColor(0, 0, 0))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Inactive, QtGui.QPalette.Text, brush)
        brush = QtGui.QBrush(QtGui.QColor(255, 255, 255))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Inactive, QtGui.QPalette.BrightText, brush)
        brush = QtGui.QBrush(QtGui.QColor(0, 0, 0))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Inactive, QtGui.QPalette.ButtonText, brush)
        brush = QtGui.QBrush(QtGui.QColor(255, 255, 255))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Inactive, QtGui.QPalette.Base, brush)
        brush = QtGui.QBrush(QtGui.QColor(233, 58, 68))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Inactive, QtGui.QPalette.Window, brush)
        brush = QtGui.QBrush(QtGui.QColor(0, 0, 0))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Inactive, QtGui.QPalette.Shadow, brush)
        brush = QtGui.QBrush(QtGui.QColor(244, 156, 161))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Inactive, QtGui.QPalette.AlternateBase, brush)
        brush = QtGui.QBrush(QtGui.QColor(255, 255, 220))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Inactive, QtGui.QPalette.ToolTipBase, brush)
        brush = QtGui.QBrush(QtGui.QColor(0, 0, 0))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Inactive, QtGui.QPalette.ToolTipText, brush)
        brush = QtGui.QBrush(QtGui.QColor(116, 29, 34))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Disabled, QtGui.QPalette.WindowText, brush)
        brush = QtGui.QBrush(QtGui.QColor(233, 58, 68))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Disabled, QtGui.QPalette.Button, brush)
        brush = QtGui.QBrush(QtGui.QColor(255, 159, 164))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Disabled, QtGui.QPalette.Light, brush)
        brush = QtGui.QBrush(QtGui.QColor(244, 108, 116))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Disabled, QtGui.QPalette.Midlight, brush)
        brush = QtGui.QBrush(QtGui.QColor(116, 29, 34))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Disabled, QtGui.QPalette.Dark, brush)
        brush = QtGui.QBrush(QtGui.QColor(155, 39, 45))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Disabled, QtGui.QPalette.Mid, brush)
        brush = QtGui.QBrush(QtGui.QColor(116, 29, 34))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Disabled, QtGui.QPalette.Text, brush)
        brush = QtGui.QBrush(QtGui.QColor(255, 255, 255))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Disabled, QtGui.QPalette.BrightText, brush)
        brush = QtGui.QBrush(QtGui.QColor(116, 29, 34))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Disabled, QtGui.QPalette.ButtonText, brush)
        brush = QtGui.QBrush(QtGui.QColor(233, 58, 68))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Disabled, QtGui.QPalette.Base, brush)
        brush = QtGui.QBrush(QtGui.QColor(233, 58, 68))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Disabled, QtGui.QPalette.Window, brush)
        brush = QtGui.QBrush(QtGui.QColor(0, 0, 0))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Disabled, QtGui.QPalette.Shadow, brush)
        brush = QtGui.QBrush(QtGui.QColor(233, 58, 68))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Disabled, QtGui.QPalette.AlternateBase, brush)
        brush = QtGui.QBrush(QtGui.QColor(255, 255, 220))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Disabled, QtGui.QPalette.ToolTipBase, brush)
        brush = QtGui.QBrush(QtGui.QColor(0, 0, 0))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Disabled, QtGui.QPalette.ToolTipText, brush)
        self.btn_run_program.setPalette(palette)
        self.btn_run_program.setFocusPolicy(QtCore.Qt.WheelFocus)
        self.btn_run_program.setAutoFillBackground(False)
        self.btn_run_program.setObjectName("btn_run_program")
        self.progressBar = QtWidgets.QProgressBar(self.frame)
        self.progressBar.setGeometry(QtCore.QRect(190, 250, 118, 23))
        self.progressBar.setProperty("value", 24)
        self.progressBar.setObjectName("progressBar")
        self.tabWidget = QtWidgets.QTabWidget(self.centralwidget)
        self.tabWidget.setGeometry(QtCore.QRect(2, 305, 1500, 541))
        self.tabWidget.setObjectName("tabWidget")
        self.tab = QtWidgets.QWidget()
        self.tab.setObjectName("tab")
        self.label_3 = QtWidgets.QLabel(self.tab)
        self.label_3.setGeometry(QtCore.QRect(20, 20, 191, 16))
        self.label_3.setObjectName("label_3")
        self.calendarWidget = QtWidgets.QCalendarWidget(self.tab)
        
        self.calendarWidget.setGeometry(QtCore.QRect(2, 60, 312, 173))
        
        
        self.calendarWidget.clicked[QtCore.QDate].connect(self.showDate)
        
        
        self.tableWidge =  QtWidgets.QTableWidget(self.tab)
        self.tableWidge.setGeometry(QtCore.QRect(320, 60, 900, 400))
        self.tableWidge.setColumnCount(10)
        self.tableWidge.setRowCount(0)
        self.tableWidge.setHorizontalHeaderLabels(['Date', 'City','State', 'Temp',"Temp Min","Temp Max", 'Pressure', 'Humdity','Description','Wind Speed'])
        
        msgBox = QtWidgets.QMessageBox()
        
        self.calendarWidget.setObjectName("calendarWidget")
        #self.listView_2 = QtWidgets.QListView(self.tab)
       # self.listView_2.setGeometry(QtCore.QRect(390, 60, 256, 192))
        #self.listView_2.setObjectName("listView_2")
        self.tabWidget.addTab(self.tab, "")
        self.tab_2 = QtWidgets.QWidget()
        self.tab_2.setObjectName("tab_2")
        
        self.graphWidget = pg.PlotWidget(self.tab_2)
        self.graphWidget.setGeometry(QtCore.QRect(320, 80, 761, 281))
       
    
        
        
        self.groupBox2 = QtWidgets.QGroupBox(self.tab_2)
        self.groupBox2.setGeometry(QtCore.QRect(5, 20, 221, 121))
        self.groupBox2.setFont(font)
        self.groupBox2.setObjectName("groupBox")
        
        self.combo = QtWidgets.QComboBox(self.groupBox2)
        self.combo.setGeometry(QtCore.QRect(10, 60, 200, 32))
        self.combo.addItem(' PRECIPITATION')
        self.combo.addItem(' MAX TEMP')
        self.combo.addItem(' MIN TEMP')
        self.combo.activated[str].connect(self.plot_figure)   
    
        
        self.groupBox3 = QtWidgets.QGroupBox(self.tab_2)
        self.groupBox3.setGeometry(QtCore.QRect(5, 300, 221, 121))
        self.groupBox3.setFont(font)
        self.groupBox2.setObjectName("groupBox")
       
    
        self.pushButton_eda = QtWidgets.QPushButton(self.groupBox3)
        self.pushButton_eda.setGeometry(QtCore.QRect(10, 20, 200, 32))
        self.pushButton_eda.setObjectName("EDA")
        self.pushButton_eda.clicked.connect(self.print_dataset_info)
    
    
    
        self.pushButton_corr_matrix = QtWidgets.QPushButton(self.groupBox3)
        self.pushButton_corr_matrix.setGeometry(QtCore.QRect(10, 45, 200, 32))
        self.pushButton_corr_matrix.setObjectName("corr_matrix")
        self.pushButton_corr_matrix.clicked.connect(self.corr_matrix)
    
    
        self.pushButton_clean_drop = QtWidgets.QPushButton(self.groupBox3)
        self.pushButton_clean_drop.setGeometry(QtCore.QRect(10, 65, 200, 32))
        self.pushButton_clean_drop.setObjectName("clean_drop")
        self.pushButton_clean_drop.clicked.connect(self.clean_dataset)
    
        
        self.pushButton_create_model = QtWidgets.QPushButton(self.groupBox3)
        self.pushButton_create_model.setGeometry(QtCore.QRect(10, 90, 200, 32))
        self.pushButton_create_model.setObjectName("create_model")
        self.pushButton_create_model.clicked.connect(self.linear_model_graph)
    
        self.msg = QtWidgets.QMessageBox()
    
        self.tabWidget.addTab(self.tab_2, "")
        
        MainWindow.setCentralWidget(self.centralwidget)
        self.menubar = QtWidgets.QMenuBar(MainWindow)
        self.menubar.setGeometry(QtCore.QRect(0, 0, 987, 22))
        self.menubar.setObjectName("menubar")
        MainWindow.setMenuBar(self.menubar)
        self.statusbar = QtWidgets.QStatusBar(MainWindow)
        self.statusbar.setObjectName("statusbar")
        MainWindow.setStatusBar(self.statusbar)

        self.retranslateUi(MainWindow)
        self.tabWidget.setCurrentIndex(0)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)
        
        self.read_in_city_list_api()
        self.read_data()
        
    #@QtCore.pyqtSlot(QtCore.QModelIndex) 
    
    def import_city_list():
        self.read_data()
        
        
        
        
    def read_data(self):
            self.dataset=pd.read_csv("Climate_Data.txt",delimiter=",")
                
                
                
                
    def create_model(self) :
            x = self.dataset.drop(' MIN TEMP' , axis = 1).values
            y = self.dataset[' MIN TEMP'].values
            X_train , X_test , Y_train , Y_test = train_test_split(x,y, test_size = 0.3 , random_state = 0)
            lnr = LinearRegression()
            print(lnr.fit(X_train,Y_train))
            y_pred = lnr.predict(X_test)
            df = pd.DataFrame({'Actual': Y_test, 'Predicted': y_pred})
            print(df)
            return df, Y_test,y_pred
    
    
    def model_fit(self):
        
        
            print("Accuracy of the model =",lnr.score(X_train, Y_train))
            print("Mean absolute error =", round(sm.mean_absolute_error(Y_test, y_pred),2)) 
            print("Mean squared error =", round(sm.mean_squared_error(Y_test, y_pred), 2)) 
            print("Median absolute error =", round(sm.median_absolute_error(Y_test, y_pred), 2)) 
            print("Explain variance score =", round(sm.explained_variance_score(Y_test, y_pred), 2)) 
            print("R2 score =", round(sm.r2_score(Y_test, y_pred), 2))
    
    
    def clean_data(self):
            print_dataset_info(dataset)
        
    
    def clear_plot(self):
        
                self.graphWidget.clear()
            
    def linear_model_graph(self):
         
                self.clear_plot()
                df, Y_test,y_pred =self.create_model()
        
                styles = {'color':'r', 'font-size':'20px'}
                self.graphWidget.setLabel('left', 'Predicted Values', **styles)
                self.graphWidget.setLabel('bottom', 'Actual values', **styles)
                self.graphWidget.setTitle("Linear Model Scatter Plot", color="b", size="30pt")
                self.graphWidget.setBackground('w')
            
            
                my_line_ref =   self.graphWidget.plot(Y_test, y_pred,pen=None,symbol='o')
        
    def corr_matrix(self):
       
        corrMatrix = self.dataset.corr()
        cmap = sns.diverging_palette(220, 10, as_cmap=True)
        plt.figure(figsize=(12, 12))
        sns.heatmap(corrMatrix,  annot=True,xticklabels=True, yticklabels=True)
        plt.show()
    
    
    
    
    def plot_figure(self,text):
        
                self.clear_plot()
                styles = {'color':'r', 'font-size':'20px'}
                self.graphWidget.setLabel('left', 'Years', **styles)
                self.graphWidget.setLabel('bottom', text, **styles)
                self.graphWidget.setTitle("Scatter Plot", color="b", size="30pt")
                self.graphWidget.setBackground('w')
                
                my_line_reff =   self.graphWidget.plot(self.dataset[text], self.dataset[' YEAR'],pen=None,symbol='o')
                 
    
        
        
    def print_dataset_info(self):
    
        print(self.dataset.head())
        print(self.dataset.shape)
        print("")
        print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")
        print("")
        print(self.dataset.describe())
        print("")
        
        print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")
        print("")
        corrMatrix = self.dataset.corr()
        print(corrMatrix)
        print("")
        print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")
        print("")
        print(self.dataset.isnull().sum())
        print("")
        print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")
        print("") 
        print( self.dataset.groupby(" YEAR")[ ' MONTH'].count())
        print("")
        print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")
        print("")
        print(list(self.dataset.columns))  
        
    def clean_dataset(self):
                self.dataset= self.dataset.drop(['COOPID'] ,axis = 1)
                self.dataset[' MEAN TEMP'] =pd.to_numeric(self.dataset[' MEAN TEMP'], errors='coerce')
                self.dataset = self.dataset.dropna()
                self.dataset = self.dataset[(self.dataset[' MAX TEMP'] >=0) & (self.dataset[' MIN TEMP'] >= 0)]
                 

    def collaspe_treeview_list(self):
        self.treeWidget.collapsed()
    
    
        
         
    def showDate(self, date):
         print(date.toString())
        
       # Debugging function
    def on_treeview_clicked(self, selected, deselected):
        
        for index in selected.indexes():
            item = self.treeWidget.itemFromIndex(index)
           
           
            print('SEL: row: %s, col: %s, text: %s' % (
                index.row(), index.column(), item.text(0)))
            parent = item.parent()
            if parent == None :
                pass 
            else :    
                find_duplication  = [i.text() for i in self.listView.findItems("", QtCore.Qt.MatchContains)]
                if ( not parent.text(0)+", "+item.text(0) in find_duplication):        
                    self.listView.insertItem(0,parent.text(0)+", "+item.text(0))
                    find_duplication.append(parent.text(0)+", "+item.text(0))
            
        for index in deselected.indexes():
            item = self.treeWidget.itemFromIndex(index)
            print('DESEL: row: %s, col: %s, text: %s' % (
                index.row(), index.column(), item.text(0)))
        
        
        #indexItem = self.treeWidget.model.index(index.row(), 0, index.parent())
        #item = self.treeWidget.selectedItems()
        #for strr in item:
           # print(strr)   
         
        #if item :
           #  baseNode = item[0]
           #  getChildNode = baseNode.text(0)
            # print (getChildNode)
            # print(index)
    
    
    
    # create GUI window setup
    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "Cities Weather API"))
        self.groupBox.setTitle(_translate("MainWindow", "Upload Cities List To Server"))
        self.groupBox2.setTitle(_translate("MainWindow", "Plot Graph"))
        self.groupBox3.setTitle(_translate("MainWindow", "Exploratory Data Analysis"))
        self.pushButton.setText(_translate("MainWindow", "Upload Cities List To Server"))
      
        
        
        self.pushButton_eda.setText(_translate("MainWindow", "Exploratory Data Anaysis"))
        self.pushButton_corr_matrix.setText(_translate("MainWindow", "Correlation Matrix"))
        
        self.pushButton_clean_drop.setText(_translate("MainWindow", "Clean Drop Dataset Column"))
        
        self.pushButton_create_model.setText(_translate("MainWindow", "Generate Model"))
        
        
       
        
        self.label_4.setText(_translate("MainWindow", "Selected"))
        #self.label_2.setText(_translate("MainWindow", "Selected"))
        self.label.setText(_translate("MainWindow", "City Sections"))
        self.btn_run_program.setText(_translate("MainWindow", "Pull Forecast "))
        self.btn_clear_listview.setText(_translate("MainWindow", "Collapse List"))
        self.label_3.setText(_translate("MainWindow", "Previous Run Lookkup"))
        self.tabWidget.setTabText(self.tabWidget.indexOf(self.tab), _translate("MainWindow", "Run Previous"))
        self.tabWidget.setTabText(self.tabWidget.indexOf(self.tab_2), _translate("MainWindow", "Admin section"))
        self.tabWidget.setTabText(self.tabWidget.indexOf(self.tab_2), _translate("MainWindow", "Data Set"))
        self.tabWidget.setTabText(self.tabWidget.indexOf(self.tab_2), _translate("MainWindow", "Graphic "))
        
        
    def test_csv():

               with open('data.csv','r') as csv_file:
                   csv_reader = csv.reader(csv_file, delimiter='|')
                   for row in csv_reader:
                         if (len(row)>1): 
                                print(row[1])
                                
                                
             # g = QtWidgets.QTreeWidgetItem(self.treeWidget, ['carrots', '0.99'])
       # QtWidgets.QTreeWidgetItem(self.treeWidget, ['tarrots', '0.99'])
       # QtWidgets.QTreeWidgetItem( g,['carrots', '0.99'])
       # QtWidgets.QTreeWidgetItem( g,['xrrots', '0.99'])                  
                                
    def  call_api_with_list(self):
    
            
             for index in range(self.listView.count()):
                  
                    val =self.listView.item(index).text().split(",")
                    self.api_call (val[1],val[0])
                    
             self.listView.clear()   
            
            
   
    
    
    # make call to weather API to populate current date information
    def api_call( self,city,state):
    
             
                    
            # Enter your API key here 
             api_key = "4812a09efe5bb760e69cac1df29a6f26"
  
           # base_url variable to store url 
             base_url = "http://api.openweathermap.org/data/2.5/weather?"
  
           
  
           # complete_url variable to store 
           # complete url address 
             complete_url = base_url + "appid=" + api_key + "&q=" + city 
             try:
           # get method of requests module 
           # return response object 
                       response = requests.get(complete_url) 
  
           # json method of response object  
           # convert json format data into 
           # python format data 
                       x = response.json() 
  
           # Now x contains# Now x contains list of nested dictionaries 
           # Check the value of "cod" key is equal to 
           # "404", means city is found otherwise, 
           
                       if x["cod"] != "404": 
                          
                           self.numRows = self.tableWidge.rowCount()
                           self.tableWidge.insertRow(self.numRows)    
                           self.tableWidge.setItem(self.numRows, 0, QtWidgets.QTableWidgetItem(str(date.today())))
                           self.tableWidge.setItem(self.numRows, 1, QtWidgets.QTableWidgetItem(city ))  
                           self.tableWidge.setItem(self.numRows, 2, QtWidgets.QTableWidgetItem(state )) 
                           y = x["main"] 
                           self.tableWidge.setItem(self.numRows, 3, QtWidgets.QTableWidgetItem(
                              str(  round( ( (int(y["temp"]) - 273.15) * 9/5 + 32 ),0)  )   ))
                           self.tableWidge.setItem(self.numRows, 4, QtWidgets.QTableWidgetItem(
                              str(  round( ( (int(y["temp_min"]) - 273.15) * 9/5 + 32 ),0)  )   ))
                            
                           self.tableWidge.setItem(self.numRows, 5, QtWidgets.QTableWidgetItem(
                              str(  round( ( (int(y["temp_max"]) - 273.15) * 9/5 + 32 ),0)  )   ))
                           self.tableWidge.setItem(self.numRows, 6, QtWidgets.QTableWidgetItem(str(y["pressure"])  ))
                           self.tableWidge.setItem(self.numRows, 7, QtWidgets.QTableWidgetItem(str(y["humidity"] ) ))    
                           z = x["weather"] 
                           zz= x ["wind"]
                           self.tableWidge.setItem(self.numRows, 8, QtWidgets.QTableWidgetItem(z[0]["description"]   ))
                           self.tableWidge.setItem(self.numRows, 9, QtWidgets.QTableWidgetItem(str(zz["speed"]) ))
                           self.add_current_weather_data(city,state,str(y["pressure"]),str(y["humidity"])
                                                         ,z[0]["description"],str(zz["speed"]),int(y["temp"]),y["temp_min"],y["temp_max"],x)  
                            
                       else : 
                
                        
                           self.msg.setWindowTitle("Info")
                           self.msg.setText("Unable to find the city data for --> " +city )
                           x = self.msg.exec_()  # this will show our messagebox
                    
                
             except Exception as e: # work on python 3.x
                             logger.error('error message  --> '+ str(e))
                    
                  
    def convert_to_fahrenheit(self,val):
                
       return  round( ( (int(val) - 273.15) * 9/5 + 32 ),0)  
    
    
    def add_current_weather_data(self,city,state,pressure,humidity,description,wind_speed,temperature,temp_min,temp_max,json):
               url = 'https://maddogonline.com/db.php'
               myobj = {'mode': 'insert','city':city,'state':state,'pressure':pressure,'humidity':humidity
                       ,'descrtiption':description,'wind_speed':wind_speed,'temperature':self.convert_to_fahrenheit(temperature),
                        'date':date.today(),'temp_min':self.convert_to_fahrenheit(temp_min),'temp_max':self.convert_to_fahrenheit(temp_max),'json':json}
               x = requests.post(url, data = myobj)
     
        
        # insert city and state data into  MYSQL database
    def update_cities_api(self,state,city):
                url = 'https://maddogonline.com/db.php'
                myobj = {'mode': 'insert_city','city':city,'state':state}
                x = requests.post(url, data = myobj)
                #print(x.text)
                
           # clear city and state data from MYSQL database     
    def delete_cities_api(self ):
                url = 'https://maddogonline.com/db.php'
                myobj = {'mode': 'clean_city_table'}
                x = requests.post(url, data = myobj)
                #print(x.json())
        
        
        # read data from MYSQL database to populate treeview widget
    def read_in_city_list_api(self):
                  myDict = {}
                  url = 'https://maddogonline.com/db.php'
                  myobj = {'mode': 'read_city'}
                  response= requests.post(url, data = myobj)
                  data = response.json()
                  # access JSOn content
                  #jsonResponse = response.json()
                  for  value in data["rec"]:
                    if value["state"] in myDict.keys(): 
                                list = myDict[value["state"]]
                                if value["city"] not in list:
                                    list.append(value["city"])
                    else: 
                                    list = []
                                    list.append(value["city"])
                                    myDict[value["state"]] = list 
                                    
                  for state, cities in myDict.items():           
                         g = QtWidgets.QTreeWidgetItem(self.treeWidget, [state, '0.99'])
                         for  city in cities :
                                QtWidgets.QTreeWidgetItem( g,[city, '0.99'])
                               
                      
                 
        # read in new city and state data to insert into MYSQL database 
    def get_csv(self):
       
        try:
            myDict = {} 
            with open('data.csv','r') as csv_file:
                    csv_reader = csv.reader(csv_file, delimiter='|')
                    city = []
                    state_short = []
                    state_long = []
                    county= []
                    city_alias= []
                   
                    for row in csv_reader:
                        if (len(row)>1): 
                           
                            if row[2] in myDict.keys(): 
                                list = myDict[row[2]]
                                if row[0] not in list:
                                    list.append(row[0])
                            else : 
                                    list = []
                                    list.append(row[0])
                                    myDict[str(row[2])] = list
                        else :
                            break;
        except Exception as e: # work on python 3.x
                   logger.error('error message  --> '+ str(e))
                         
        self.delete_cities_api ()         
        for state, cities in myDict.items():           
                  g = QtWidgets.QTreeWidgetItem(self.treeWidget, [state, '0.99'])
                  for  city in cities :
                      QtWidgets.QTreeWidgetItem( g,[city, '0.99'])
                      self.update_cities_api(state,city)

# %%
#https://www.learnpyqt.com/courses/graphics-plotting/plotting-pyqtgraph/

# %%
if __name__ == "__main__":
    import sys
    logger = logging
    logger.Logger('catch_all')
    app = QtWidgets.QApplication(sys.argv)
    MainWindow = QtWidgets.QMainWindow()
    ui = Ui_MainWindow()
    ui.setupUi(MainWindow)
    #ui.get_csv()
  
   
    #ui.plot_figure()
 
    MainWindow.show()
    
    sys.exit(app.exec_())
